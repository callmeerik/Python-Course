# %% [markdown]
# # **Reporting Data**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### **Create Fake Information**

# %%
# Datos para el DataFrame
airlines = ['LATAM', 'Avianca', 'Gol', 'Aerolineas Argentinas', 'United', 'American']
# Códigos de aeropuertos de Sudamérica y algunos de conexión
airports = ['GRU', 'EZE', 'BOG', 'LIM', 'SCL', 'GIG', 'JFK', 'MIA']
statuses = ['On Time', 'Delayed', 'Cancelled']
num_observations = 35

data = {
    'flight_id': [f'FL{i:03}' for i in range(1, num_observations + 1)],
    'airline': np.random.choice(airlines, num_observations),
    'origin_airport': np.random.choice(airports, num_observations),
    'destination_airport': np.random.choice(airports, num_observations),
    'passengers': np.random.randint(100, 250, size=num_observations),
    'status': np.random.choice(statuses, num_observations, p=[0.7, 0.2, 0.1]),
    'price': np.random.randint(200, 1500, size=num_observations),
    'flight_date': pd.to_datetime(pd.date_range(start='2025-01-01', periods=num_observations, freq='D'))
}

# Asegurarse de que el origen y el destino no sean el mismo para cada vuelo
for i in range(num_observations):
    while data['origin_airport'][i] == data['destination_airport'][i]:
        data['destination_airport'][i] = np.random.choice(airports)

df = pd.DataFrame(data)

df.head()
# Out:
#   flight_id  airline origin_airport destination_airport  passengers   status  \
# 0     FL001    LATAM            GIG                 EZE         214  On Time
# 1     FL002   United            GIG                 GRU         175  On Time
# 2     FL003   United            GRU                 EZE         160  On Time
# 3     FL004   United            LIM                 BOG         230  Delayed
# 4     FL005  Avianca            EZE                 MIA         115  On Time
#
#    price flight_date
# 0    597  2025-01-01
# 1    543  2025-01-02
# 2    701  2025-01-03
# 3   1305  2025-01-04
# 4   1386  2025-01-05

# %% [markdown]
# ## **Group By**

# %% [markdown]
# **See the average price by airline**

# %%
avg_price_airline = df.groupby("airline")["price"].mean()
avg_price_airline
# Out:
# airline
# Aerolineas Argentinas     696.333333
# American                 1076.000000
# Avianca                   886.000000
# Gol                      1007.333333
# LATAM                     648.666667
# United                    815.571429
# Name: price, dtype: float64

# %% [markdown]
# **See the number of passengers by airline and status flight**

# %%
num_passengers = df.groupby( ["airline", "status"] )["passengers"].sum()
num_passengers
# Out:
# airline                status
# Aerolineas Argentinas  Delayed       129
#                        On Time       282
# American               Delayed       155
#                        On Time      1027
# Avianca                Delayed       204
#                        On Time       856
# Gol                    Cancelled     138
#                        Delayed       454
#                        On Time       267
# LATAM                  Cancelled     310
#                        Delayed       189
#                        On Time       496
# United                 Delayed       409
#                        On Time       956
# Name: passengers, dtype: int32

# %% [markdown]
# **Give a report about the avg of passengers and avg price by airline**

# %%
summary = df.groupby("airline")[["passengers", "price"]].mean()
summary
# Out:
#                        passengers        price
# airline
# Aerolineas Argentinas  137.000000   696.333333
# American               168.857143  1076.000000
# Avianca                176.666667   886.000000
# Gol                    143.166667  1007.333333
# LATAM                  165.833333   648.666667
# United                 195.000000   815.571429

# %%
summary1 = df.groupby("origin_airport").agg(
    {
        "price": "mean",
        "passengers": "sum"
    }
)

summary1
# Out:
#                       price  passengers
# origin_airport
# BOG              947.833333        1119
# EZE              888.750000         613
# GIG              772.125000        1350
# GRU              873.000000         677
# JFK              614.000000         308
# LIM             1105.333333         601
# MIA              808.750000         669
# SCL             1006.333333         535

# %%
summary1 = df.groupby("origin_airport").agg(
    avg_price = ("price", "mean"),
    total_passengers = ("passengers", "sum")
)

summary1
# Out:
#                   avg_price  total_passengers
# origin_airport
# BOG              947.833333              1119
# EZE              888.750000               613
# GIG              772.125000              1350
# GRU              873.000000               677
# JFK              614.000000               308
# LIM             1105.333333               601
# MIA              808.750000               669
# SCL             1006.333333               535

# %% [markdown]
# **How many flights does each airline have per airport?**

# %%
summary2 = df.groupby(["airline", "origin_airport"]).agg({
    "origin_airport": "count"
})

summary2
# Out:
#                                       origin_airport
# airline               origin_airport
# Aerolineas Argentinas GIG                          1
#                       GRU                          2
# American              BOG                          1
#                       EZE                          1
#                       GIG                          1
#                       JFK                          1
#                       MIA                          1
#                       SCL                          2
# Avianca               BOG                          1
#                       EZE                          1
#                       JFK                          1
#                       LIM                          1
#                       MIA                          1
#                       SCL                          1
# Gol                   GIG                          2
#                       GRU                          1
#                       LIM                          1
#                       MIA                          2
# LATAM                 BOG                          1
#                       EZE                          2
#                       GIG                          2
#                       GRU                          1
# United                BOG                          3
#                       GIG                          2
#                       GRU                          1
#                       LIM                          1

# %% [markdown]
# ## **Pivot Tables***

# %%
avg_price_by_airline = df.pivot_table(
    index='airline',
    values='price',
    aggfunc='mean'
)

avg_price_by_airline
# Out:
#                              price
# airline
# Aerolineas Argentinas   696.333333
# American               1076.000000
# Avianca                 886.000000
# Gol                    1007.333333
# LATAM                   648.666667
# United                  815.571429

# %%
avg_price_by_route = df.pivot_table(
    index=['airline', 'origin_airport'],
    values='price',
    aggfunc='mean'
)

avg_price_by_route
# Out:
#                                             price
# airline               origin_airport
# Aerolineas Argentinas GIG              336.000000
#                       GRU              876.500000
# American              BOG             1059.000000
#                       EZE             1232.000000
#                       GIG             1290.000000
#                       JFK              966.000000
#                       MIA              791.000000
#                       SCL             1097.000000
# Avianca               BOG             1325.000000
#                       EZE             1386.000000
#                       JFK              262.000000
#                       LIM             1086.000000
#                       MIA              432.000000
#                       SCL              825.000000
# Gol                   GIG             1074.500000
#                       GRU              958.000000
#                       LIM              925.000000
#                       MIA             1006.000000
# LATAM                 BOG             1048.000000
#                       EZE              468.500000
#                       GIG              477.000000
#                       GRU              953.000000
# United                BOG              751.666667
#                       GIG              724.000000
#                       GRU              701.000000
#                       LIM             1305.000000

# %%
passenger_summary = df.pivot_table(
    index='airline',
    values='passengers',
    aggfunc=['mean', 'sum']
)

passenger_summary
# Out:
#                              mean        sum
#                        passengers passengers
# airline
# Aerolineas Argentinas  137.000000        411
# American               168.857143       1182
# Avianca                176.666667       1060
# Gol                    143.166667        859
# LATAM                  165.833333        995
# United                 195.000000       1365

# %%
passenger_summary = df.pivot_table(
    index='airline',
    values= ["passengers", "price"],
    aggfunc={"passengers":'sum', "price":"mean"}
)
passenger_summary
# Out:
#                        passengers        price
# airline
# Aerolineas Argentinas         411   696.333333
# American                     1182  1076.000000
# Avianca                      1060   886.000000
# Gol                           859  1007.333333
# LATAM                         995   648.666667
# United                       1365   815.571429

# %% [markdown]
# ---
