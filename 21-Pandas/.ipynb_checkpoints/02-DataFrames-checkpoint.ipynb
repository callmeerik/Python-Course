# %% [markdown]
# # 📘 **DataFrames**
#
# A DataFrame is the second data structure provided by Pandas library. It is a 2-dimensional data structure, build it with rows and columns.
#
# **Key Characteristics**
#
# * **2-Dimensions:** Rows and columns
# * **Heterogenous:** The values can be of different types in the different columns
# * **Mutable:** Each value in dataframes can be changed
# * **Labeled Axes:** Dataframes have both row index and column index

# %%
import pandas as pd

# %% [markdown]
# ## **Create DataFrames**

# %% [markdown]
# **Dataframe from a list of lists**

# %%
data_list = [
    ["Alice", 28, "Data Engineer"],
    ["Dante", 35, "Finance Analyst"],
    ["Bob", 21, "HR Analyst Junior"]
]

df_from_list = pd.DataFrame( data= data_list, columns=["name", "age", "position"] )
df_from_list
# Out:
#     name  age           position
# 0  Alice   28      Data Engineer
# 1  Dante   35    Finance Analyst
# 2    Bob   21  HR Analyst Junior

# %% [markdown]
# **DataFrame From a Dictionary**

# %%
data_dict = {
    "product_name": ["Play Station 5", "Xbox Series X", "Tv LG 32\""],
    "category": ["Console", "Console", "Tvs"],
    "price": [599.99, 599.99, 242.99]
}

df_dict = pd.DataFrame(data_dict)
df_dict
# Out:
#      product_name category   price
# 0  Play Station 5  Console  599.99
# 1   Xbox Series X  Console  599.99
# 2       Tv LG 32"      Tvs  242.99

# %% [markdown]
# **DataFrame with Specific Index**

# %%
champions_league_results = {
    'matches': [
        
        {
            'local_team': 'Real Madrid',
            'guest_team': 'Olympique de Marseille',
            'local_goals': 2,
            'guest_goals': 1,
            'date_time': '2025-09-16 20:00',
            'stadium': 'Santiago Bernabéu Stadium',
            'country': 'Spain'
        },
        {
            'local_team': 'Juventus',
            'guest_team': 'Borussia Dortmund',
            'local_goals': 4,
            'guest_goals': 4,
            'date_time': '2025-09-16 20:00',
            'stadium': 'Allianz Stadium',
            'country': 'Italy'
        },
        {
            'local_team': 'S.L. Benfica',
            'guest_team': 'Qarabağ FK',
            'local_goals': 2,
            'guest_goals': 3,
            'date_time': '2025-09-16 20:00',
            'stadium': 'Estádio da Luz',
            'country': 'Portugal'
        },
        {
            'local_team': 'Tottenham Hotspur F.C.',
            'guest_team': 'Villarreal CF',
            'local_goals': 1,
            'guest_goals': 0,
            'date_time': '2025-09-16 20:00',
            'stadium': 'Tottenham Hotspur Stadium',
            'country': 'England'
        },
        {
            'local_team': 'Athletic Club',
            'guest_team': 'Arsenal F.C.',
            'local_goals': 0,
            'guest_goals': 2,
            'date_time': '2025-09-16 20:00',
            'stadium': 'San Mamés Stadium',
            'country': 'Spain'
        },
        {
            'local_team': 'PSV',
            'guest_team': 'Royale Union Saint-Gilloise',
            'local_goals': 1,
            'guest_goals': 3,
            'date_time': '2025-09-16 20:00',
            'stadium': 'Philips Stadion',
            'country': 'Netherlands'
        },
        
        {
            'local_team': 'Liverpool',
            'guest_team': 'Atletico de Madrid',
            'local_goals': 3,
            'guest_goals': 2,
            'date_time': '2025-09-17 20:00',
            'stadium': 'Anfield',
            'country': 'England'
        },
        {
            'local_team': 'FC Bayern Munich',
            'guest_team': 'Chelsea F.C.',
            'local_goals': 3,
            'guest_goals': 1,
            'date_time': '2025-09-17 20:00',
            'stadium': 'Allianz Arena',
            'country': 'Germany'
        },
        {
            'local_team': 'Paris Saint-Germain F.C.',
            'guest_team': 'Atalanta BC',
            'local_goals': 4,
            'guest_goals': 0,
            'date_time': '2025-09-17 20:00',
            'stadium': 'Parc des Princes',
            'country': 'France'
        },
        {
            'local_team': 'AFC Ajax',
            'guest_team': 'Inter Milan',
            'local_goals': 0,
            'guest_goals': 2,
            'date_time': '2025-09-17 20:00',
            'stadium': 'Johan Cruyff Arena',
            'country': 'Netherlands'
        },
        {
            'local_team': 'SK Slavia Prague',
            'guest_team': 'FK Bodø/Glimt',
            'local_goals': 2,
            'guest_goals': 2,
            'date_time': '2025-09-17 20:00',
            'stadium': 'Fortuna Arena',
            'country': 'Czech Republic'
        },
        {
            'local_team': 'Olympiacos F.C.',
            'guest_team': 'Pafos FC',
            'local_goals': 0,
            'guest_goals': 0,
            'date_time': '2025-09-17 20:00',
            'stadium': 'Karaiskakis Stadium',
            'country': 'Greece'
        }
    ]
}

# %%
df_ucl = pd.DataFrame(champions_league_results["matches"], 
                      index=["A", "B", "C", "D", "E", "f", "G", "H",
                            "I", "J", "K", "L"])

# %%
df_ucl
# Out:
#                  local_team                   guest_team  local_goals  \
# A               Real Madrid       Olympique de Marseille            2
# B                  Juventus            Borussia Dortmund            4
# C              S.L. Benfica                   Qarabağ FK            2
# D    Tottenham Hotspur F.C.                Villarreal CF            1
# E             Athletic Club                 Arsenal F.C.            0
# f                       PSV  Royale Union Saint-Gilloise            1
# G                 Liverpool           Atletico de Madrid            3
# H          FC Bayern Munich                 Chelsea F.C.            3
# I  Paris Saint-Germain F.C.                  Atalanta BC            4
# J                  AFC Ajax                  Inter Milan            0
# K          SK Slavia Prague                FK Bodø/Glimt            2
# L           Olympiacos F.C.                     Pafos FC            0
#
#    guest_goals         date_time                    stadium         country
# A            1  2025-09-16 20:00  Santiago Bernabéu Stadium           Spain
# B            4  2025-09-16 20:00            Allianz Stadium           Italy
# C            3  2025-09-16 20:00             Estádio da Luz        Portugal
# D            0  2025-09-16 20:00  Tottenham Hotspur Stadium         England
# E            2  2025-09-16 20:00          San Mamés Stadium           Spain
# f            3  2025-09-16 20:00            Philips Stadion     Netherlands
# G            2  2025-09-17 20:00                    Anfield         England
# H            1  2025-09-17 20:00              Allianz Arena         Germany
# I            0  2025-09-17 20:00           Parc des Princes          France
# J            2  2025-09-17 20:00         Johan Cruyff Arena     Netherlands
# K            2  2025-09-17 20:00              Fortuna Arena  Czech Republic
# L            0  2025-09-17 20:00        Karaiskakis Stadium          Greece

# %% [markdown]
# ## **Selection and Indexing**

# %%
# select a specific column
df_ucl["local_goals"]
# Out:
# A    2
# B    4
# C    2
# D    1
# E    0
# f    1
# G    3
# H    3
# I    4
# J    0
# K    2
# L    0
# Name: local_goals, dtype: int64

# %%
# select a specific row by numerical index
df_ucl.iloc[2]
# Out:
# local_team         S.L. Benfica
# guest_team           Qarabağ FK
# local_goals                   2
# guest_goals                   3
# date_time      2025-09-16 20:00
# stadium          Estádio da Luz
# country                Portugal
# Name: C, dtype: object

# %%
# select specific row by object index
df_ucl.loc["K"]
# Out:
# local_team     SK Slavia Prague
# guest_team        FK Bodø/Glimt
# local_goals                   2
# guest_goals                   2
# date_time      2025-09-17 20:00
# stadium           Fortuna Arena
# country          Czech Republic
# Name: K, dtype: object

# %%
# select a group of rows
df_ucl[0: 4]
# Out:
#                local_team              guest_team  local_goals  guest_goals  \
# A             Real Madrid  Olympique de Marseille            2            1
# B                Juventus       Borussia Dortmund            4            4
# C            S.L. Benfica              Qarabağ FK            2            3
# D  Tottenham Hotspur F.C.           Villarreal CF            1            0
#
#           date_time                    stadium   country
# A  2025-09-16 20:00  Santiago Bernabéu Stadium     Spain
# B  2025-09-16 20:00            Allianz Stadium     Italy
# C  2025-09-16 20:00             Estádio da Luz  Portugal
# D  2025-09-16 20:00  Tottenham Hotspur Stadium   England

# %%
# select more than 1 columns
df_ucl[["local_team", "local_goals"]]
# Out:
#                  local_team  local_goals
# A               Real Madrid            2
# B                  Juventus            4
# C              S.L. Benfica            2
# D    Tottenham Hotspur F.C.            1
# E             Athletic Club            0
# f                       PSV            1
# G                 Liverpool            3
# H          FC Bayern Munich            3
# I  Paris Saint-Germain F.C.            4
# J                  AFC Ajax            0
# K          SK Slavia Prague            2
# L           Olympiacos F.C.            0

# %%
# select specific number of rows with head()
df_ucl.head(3)
# Out:
#      local_team              guest_team  local_goals  guest_goals  \
# A   Real Madrid  Olympique de Marseille            2            1
# B      Juventus       Borussia Dortmund            4            4
# C  S.L. Benfica              Qarabağ FK            2            3
#
#           date_time                    stadium   country
# A  2025-09-16 20:00  Santiago Bernabéu Stadium     Spain
# B  2025-09-16 20:00            Allianz Stadium     Italy
# C  2025-09-16 20:00             Estádio da Luz  Portugal

# %% [markdown]
# ### **Filter Data**

# %%
df_ucl[df_ucl["local_goals"] < 3]
# Out:
#                local_team                   guest_team  local_goals  \
# A             Real Madrid       Olympique de Marseille            2
# C            S.L. Benfica                   Qarabağ FK            2
# D  Tottenham Hotspur F.C.                Villarreal CF            1
# E           Athletic Club                 Arsenal F.C.            0
# f                     PSV  Royale Union Saint-Gilloise            1
# J                AFC Ajax                  Inter Milan            0
# K        SK Slavia Prague                FK Bodø/Glimt            2
# L         Olympiacos F.C.                     Pafos FC            0
#
#    guest_goals         date_time                    stadium         country
# A            1  2025-09-16 20:00  Santiago Bernabéu Stadium           Spain
# C            3  2025-09-16 20:00             Estádio da Luz        Portugal
# D            0  2025-09-16 20:00  Tottenham Hotspur Stadium         England
# E            2  2025-09-16 20:00          San Mamés Stadium           Spain
# f            3  2025-09-16 20:00            Philips Stadion     Netherlands
# J            2  2025-09-17 20:00         Johan Cruyff Arena     Netherlands
# K            2  2025-09-17 20:00              Fortuna Arena  Czech Republic
# L            0  2025-09-17 20:00        Karaiskakis Stadium          Greece

# %%
df_ucl[df_ucl["local_goals"] < 3]["local_team"]
# Out:
# A               Real Madrid
# C              S.L. Benfica
# D    Tottenham Hotspur F.C.
# E             Athletic Club
# f                       PSV
# J                  AFC Ajax
# K          SK Slavia Prague
# L           Olympiacos F.C.
# Name: local_team, dtype: object

# %%
df_ucl[ df_ucl["country"] == "Spain" ]
# Out:
#       local_team              guest_team  local_goals  guest_goals  \
# A    Real Madrid  Olympique de Marseille            2            1
# E  Athletic Club            Arsenal F.C.            0            2
#
#           date_time                    stadium country
# A  2025-09-16 20:00  Santiago Bernabéu Stadium   Spain
# E  2025-09-16 20:00          San Mamés Stadium   Spain

# %%
df_ucl[ (df_ucl["country"] == "Spain") | (df_ucl["country"] == "Germany") ]
# Out:
#          local_team              guest_team  local_goals  guest_goals  \
# A       Real Madrid  Olympique de Marseille            2            1
# E     Athletic Club            Arsenal F.C.            0            2
# H  FC Bayern Munich            Chelsea F.C.            3            1
#
#           date_time                    stadium  country
# A  2025-09-16 20:00  Santiago Bernabéu Stadium    Spain
# E  2025-09-16 20:00          San Mamés Stadium    Spain
# H  2025-09-17 20:00              Allianz Arena  Germany

# %%
df_ucl[ df_ucl["country"].isin(["Germany", "France"]) ]
# Out:
#                  local_team    guest_team  local_goals  guest_goals  \
# H          FC Bayern Munich  Chelsea F.C.            3            1
# I  Paris Saint-Germain F.C.   Atalanta BC            4            0
#
#           date_time           stadium  country
# H  2025-09-17 20:00     Allianz Arena  Germany
# I  2025-09-17 20:00  Parc des Princes   France

# %% [markdown]
# ### **Add New Columns**

# %%
df_ucl["diff_local_goals"] = df_ucl["local_goals"] - df_ucl["guest_goals"]

# %% [markdown]
# ### **Applying custom functions**
#
# We can create new columns applying custom functions using the ".apply()" method, this methods receive some arguments like the name of function and the axis.
#
# * **axis=1:** Apply function row-wise (when we want to access the data of two or more rows)
# * **axis=0:** Apply function column-wise

# %%
# using a custom function
def diff_guest_goals(row):
    return row["guest_goals"] - row["local_goals"]

# %%
df_ucl["diff_guest_goals"] = df_ucl.apply( diff_guest_goals, axis=1 )
df_ucl.head()
# Out:
#                local_team              guest_team  local_goals  guest_goals  \
# A             Real Madrid  Olympique de Marseille            2            1
# B                Juventus       Borussia Dortmund            4            4
# C            S.L. Benfica              Qarabağ FK            2            3
# D  Tottenham Hotspur F.C.           Villarreal CF            1            0
# E           Athletic Club            Arsenal F.C.            0            2
#
#           date_time                    stadium   country  diff_local_goals  \
# A  2025-09-16 20:00  Santiago Bernabéu Stadium     Spain                 1
# B  2025-09-16 20:00            Allianz Stadium     Italy                 0
# C  2025-09-16 20:00             Estádio da Luz  Portugal                -1
# D  2025-09-16 20:00  Tottenham Hotspur Stadium   England                 1
# E  2025-09-16 20:00          San Mamés Stadium     Spain                -2
#
#    diff_guest_goals
# A                -1
# B                 0
# C                 1
# D                -1
# E                 2

# %% [markdown]
# ### **Delete Columns**
#
# Using the **.drop()** method, we can delete columns, specifiyng the axis
#
# * **axis=1:** Drop columns
# * **axis=0:** Drop rows

# %%
df_ucl.drop("diff_local_goals", axis=1)
# Out:
#                  local_team                   guest_team  local_goals  \
# A               Real Madrid       Olympique de Marseille            2
# B                  Juventus            Borussia Dortmund            4
# C              S.L. Benfica                   Qarabağ FK            2
# D    Tottenham Hotspur F.C.                Villarreal CF            1
# E             Athletic Club                 Arsenal F.C.            0
# f                       PSV  Royale Union Saint-Gilloise            1
# G                 Liverpool           Atletico de Madrid            3
# H          FC Bayern Munich                 Chelsea F.C.            3
# I  Paris Saint-Germain F.C.                  Atalanta BC            4
# J                  AFC Ajax                  Inter Milan            0
# K          SK Slavia Prague                FK Bodø/Glimt            2
# L           Olympiacos F.C.                     Pafos FC            0
#
#    guest_goals         date_time                    stadium         country  \
# A            1  2025-09-16 20:00  Santiago Bernabéu Stadium           Spain
# B            4  2025-09-16 20:00            Allianz Stadium           Italy
# C            3  2025-09-16 20:00             Estádio da Luz        Portugal
# D            0  2025-09-16 20:00  Tottenham Hotspur Stadium         England
# E            2  2025-09-16 20:00          San Mamés Stadium           Spain
# f            3  2025-09-16 20:00            Philips Stadion     Netherlands
# G            2  2025-09-17 20:00                    Anfield         England
# H            1  2025-09-17 20:00              Allianz Arena         Germany
# I            0  2025-09-17 20:00           Parc des Princes          France
# J            2  2025-09-17 20:00         Johan Cruyff Arena     Netherlands
# K            2  2025-09-17 20:00              Fortuna Arena  Czech Republic
# L            0  2025-09-17 20:00        Karaiskakis Stadium          Greece
#
#    diff_guest_goals
# A                -1
# B                 0
# C                 1
# D                -1
# E                 2
# f                 2
# G                -1
# H                -2
# I                -4
# J                 2
# K                 0
# L                 0

# %% [markdown]
# ## **Getting Information About DataFrames**

# %%
# see the shape
df_ucl.shape
# Out:
# (12, 9)

# %%
# see an overview of information
df_ucl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, A to L
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   local_team        12 non-null     object
#  1   guest_team        12 non-null     object
#  2   local_goals       12 non-null     int64
#  3   guest_goals       12 non-null     int64
#  4   date_time         12 non-null     object
#  5   stadium           12 non-null     object
#  6   country           12 non-null     object
#  7   diff_local_goals  12 non-null     int64
#  8   diff_guest_goals  12 non-null     int64
# dtypes: int64(4), object(5)
# memory usage: 1.2+ KB

# %%
# see data types
df_ucl.dtypes
# Out:
# local_team          object
# guest_team          object
# local_goals          int64
# guest_goals          int64
# date_time           object
# stadium             object
# country             object
# diff_local_goals     int64
# diff_guest_goals     int64
# dtype: object

# %%
# see the column names
df_ucl.columns
# Out:
# Index(['local_team', 'guest_team', 'local_goals', 'guest_goals', 'date_time',
#        'stadium', 'country', 'diff_local_goals', 'diff_guest_goals'],
#       dtype='object')
